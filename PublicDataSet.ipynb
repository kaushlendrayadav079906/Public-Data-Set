# %% [markdown]
# <a href="https://colab.research.google.com/github/kaushlendrayadav079906/Public-Data-Set/blob/main/PublicDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Employee.csv')

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(1889)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  2764.000000  2764.000000  2764.000000                2764.000000
# mean   2015.090449     2.636035    30.952967                   2.644356
# std       1.885943     0.624001     5.108872                   1.610610
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     2.000000    27.000000                   1.000000
# 50%    2015.000000     3.000000    30.000000                   2.000000
# 75%    2017.000000     3.000000    35.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  2764.000000
# mean      0.393632
# std       0.488643
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist(figsize=(12,10))
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
# Final Report

print("======================================")
print(" EXPLORATORY DATA ANALYSIS REPORT ")
print("======================================")

print("\n1. Dataset Information")
print("-----------------------")
print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])

print("\nColumns in Dataset:")
print(df.columns.tolist())

print("\n2. Missing Values")
print("-----------------------")
print(df.isnull().sum())

print("\n3. Duplicate Values")
print("-----------------------")
print("Duplicate Rows :", df.duplicated().sum())

print("\n4. Statistical Summary")
print("-----------------------")
print(df.describe())

print("\n5. Key Insights")
print("-----------------------")
print("1. Data cleaned successfully.")
print("2. Missing values handled.")
print("3. Duplicate records removed.")
print("4. Correlation between variables analyzed.")
print("5. Visualization graphs generated successfully.")

print("\n6. Conclusion")
print("-----------------------")
print("EDA helped in understanding the dataset patterns,")
print("relationships, distributions, and important insights.")
print("This analysis can be useful for prediction and decision making.")
# Out:
# ...
#  EXPLORATORY DATA ANALYSIS REPORT
# ...
#
# 1. Dataset Information
# -----------------------
# Number of Rows : 2764
# Number of Columns : 9
#
# Columns in Dataset:
# ['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender', 'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot']
#
# 2. Missing Values
# -----------------------
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64
#
# 3. Duplicate Values
# -----------------------
# Duplicate Rows : 0
#
# 4. Statistical Summary
# -----------------------
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  2764.000000  2764.000000  2764.000000                2764.000000
# mean   2015.090449     2.636035    30.952967                   2.644356
# ...
